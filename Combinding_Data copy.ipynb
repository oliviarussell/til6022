# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# January 2019
df2019JanOne = pd.read_csv("Data/yellow_tripdata_2019-01cleanpart1.csv", index_col = 0)
df2019JanTwo = pd.read_csv("Data/yellow_tripdata_2019-01cleanpart2.csv", index_col = 0)
df2019JanThree = pd.read_csv("Data/yellow_tripdata_2019-01cleanpart3.csv", index_col = 0)
df2019Jan = pd.concat([df2019JanOne, df2019JanTwo, df2019JanThree], ignore_index = True) # Ignore index set to True to be sure no overlap is created; should not be necessary.
df2019Jan.index.name = "Index"

# February 2019
df2019FebOne = pd.read_csv("Data/yellow_tripdata_2019-02cleanpart1.csv", index_col = 0)
df2019FebTwo = pd.read_csv("Data/yellow_tripdata_2019-02cleanpart2.csv", index_col = 0)
df2019FebThree = pd.read_csv("Data/yellow_tripdata_2019-02cleanpart3.csv", index_col = 0)
df2019Feb = pd.concat([df2019FebOne, df2019FebTwo, df2019FebThree], ignore_index = True)
df2019Feb.index.name = "Index"

# March 2019
df2019MarOne = pd.read_csv("Data/yellow_tripdata_2019-03cleanpart1.csv", index_col = 0)
df2019MarTwo = pd.read_csv("Data/yellow_tripdata_2019-03cleanpart2.csv", index_col = 0)
df2019MarThree = pd.read_csv("Data/yellow_tripdata_2019-03cleanpart3.csv", index_col = 0)
df2019Mar = pd.concat([df2019MarOne, df2019MarTwo, df2019MarThree], ignore_index = True)
df2019Mar.index.name = "Index"

# April 2019
df2019AprOne = pd.read_csv("Data/yellow_tripdata_2019-04cleanpart1.csv", index_col = 0)
df2019AprTwo = pd.read_csv("Data/yellow_tripdata_2019-04cleanpart2.csv", index_col = 0)
df2019AprThree = pd.read_csv("Data/yellow_tripdata_2019-04cleanpart3.csv", index_col = 0)
df2019Apr = pd.concat([df2019AprOne, df2019AprTwo, df2019AprThree], ignore_index = True)
df2019Apr.index.name = "Index"

# May 2019
df2019MayOne = pd.read_csv("Data/yellow_tripdata_2019-05cleanpart1.csv", index_col = 0)
df2019MayTwo = pd.read_csv("Data/yellow_tripdata_2019-05cleanpart2.csv", index_col = 0)
df2019MayThree = pd.read_csv("Data/yellow_tripdata_2019-05cleanpart3.csv", index_col = 0)
df2019May = pd.concat([df2019MayOne, df2019MayTwo, df2019MayThree], ignore_index = True)
df2019May.index.name = "Index"

# June 2019
df2019JunOne = pd.read_csv("Data/yellow_tripdata_2019-06cleanpart1.csv", index_col = 0)
df2019JunTwo = pd.read_csv("Data/yellow_tripdata_2019-06cleanpart2.csv", index_col = 0)
df2019JunThree = pd.read_csv("Data/yellow_tripdata_2019-06cleanpart3.csv", index_col = 0)
df2019Jun = pd.concat([df2019JunOne, df2019JunTwo, df2019JunThree], ignore_index = True)
df2019Jun.index.name = "Index"

# July 2019
df2019JulOne = pd.read_csv("Data/yellow_tripdata_2019-07cleanpart1.csv", index_col = 0)
df2019JulTwo = pd.read_csv("Data/yellow_tripdata_2019-07cleanpart2.csv", index_col = 0)
df2019Jul = pd.concat([df2019JulOne, df2019JulTwo], ignore_index = True)
df2019Jul.index.name = "Index"

# Augustus 2019
df2019AugOne = pd.read_csv("Data/yellow_tripdata_2019-08cleanpart1.csv", index_col = 0)
df2019AugTwo = pd.read_csv("Data/yellow_tripdata_2019-08cleanpart2.csv", index_col = 0)
df2019Aug = pd.concat([df2019AugOne, df2019AugTwo], ignore_index = True)
df2019Aug.index.name = "Index"

# September 2019
df2019SepOne = pd.read_csv("Data/yellow_tripdata_2019-09cleanpart1.csv", index_col = 0)
df2019SepTwo = pd.read_csv("Data/yellow_tripdata_2019-09cleanpart2.csv", index_col = 0)
df2019SepThree = pd.read_csv("Data/yellow_tripdata_2019-09cleanpart3.csv", index_col = 0)
df2019Sep = pd.concat([df2019SepOne, df2019SepTwo, df2019SepThree], ignore_index = True)
df2019Sep.index.name = "Index"

# October 2019
df2019OctOne = pd.read_csv("Data/yellow_tripdata_2019-10cleanpart1.csv", index_col = 0)
df2019OctTwo = pd.read_csv("Data/yellow_tripdata_2019-10cleanpart2.csv", index_col = 0)
df2019OctThree = pd.read_csv("Data/yellow_tripdata_2019-10cleanpart3.csv", index_col = 0)
df2019Oct = pd.concat([df2019OctOne, df2019OctTwo, df2019OctThree], ignore_index = True)
df2019Oct.index.name = "Index"

# November 2019
df2019NovOne = pd.read_csv("Data/yellow_tripdata_2019-11cleanpart1.csv", index_col = 0)
df2019NovTwo = pd.read_csv("Data/yellow_tripdata_2019-11cleanpart2.csv", index_col = 0)
df2019NovThree = pd.read_csv("Data/yellow_tripdata_2019-11cleanpart3.csv", index_col = 0)
df2019Nov = pd.concat([df2019NovOne, df2019NovTwo, df2019NovThree], ignore_index = True)
df2019Nov.index.name = "Index"

# December 2019
df2019DecOne = pd.read_csv("Data/yellow_tripdata_2019-12cleanpart1.csv", index_col = 0)
df2019DecTwo = pd.read_csv("Data/yellow_tripdata_2019-12cleanpart2.csv", index_col = 0)
df2019DecThree = pd.read_csv("Data/yellow_tripdata_2019-12cleanpart3.csv", index_col = 0)
df2019Dec = pd.concat([df2019DecOne, df2019DecTwo, df2019DecThree], ignore_index = True)
df2019Dec.index.name = "Index"

# %%
# January 2020
df2020JanOne = pd.read_csv("Data/yellow_tripdata_2020-01cleanpart1.csv", index_col = 0)
df2020JanTwo = pd.read_csv("Data/yellow_tripdata_2020-01cleanpart2.csv", index_col = 0)
df2020Jan = pd.concat([df2020JanOne, df2020JanTwo], ignore_index = True)
df2020Jan.index.name = "Index"

# February 2020
df2020FebOne = pd.read_csv("Data/yellow_tripdata_2020-02cleanpart1.csv", index_col = 0)
df2020FebTwo = pd.read_csv("Data/yellow_tripdata_2020-02cleanpart2.csv", index_col = 0)
df2020Feb = pd.concat([df2020FebOne, df2020FebTwo], ignore_index = True)
df2020Feb.index.name = "Index"

# All months after the start of COVID in 2020
df2020Mar = pd.read_csv("Data/yellow_tripdata_2020-03clean.csv", index_col = 0)
df2020Mar.index.name = "Index"
df2020Apr = pd.read_csv("Data/yellow_tripdata_2020-04clean.csv", index_col = 0)
df2020Apr.index.name = "Index"
df2020May = pd.read_csv("Data/yellow_tripdata_2020-05clean.csv", index_col = 0)
df2020May.index.name = "Index"
df2020Jun = pd.read_csv("Data/yellow_tripdata_2020-06clean.csv", index_col = 0)
df2020Jun.index.name = "Index"
df2020Jul = pd.read_csv("Data/yellow_tripdata_2020-07clean.csv", index_col = 0)
df2020Jul.index.name = "Index"
df2020Aug = pd.read_csv("Data/yellow_tripdata_2020-08clean.csv", index_col = 0)
df2020Aug.index.name = "Index"
df2020Sep = pd.read_csv("Data/yellow_tripdata_2020-09clean.csv", index_col = 0)
df2020Sep.index.name = "Index"
df2020Oct = pd.read_csv("Data/yellow_tripdata_2020-10clean.csv", index_col = 0)
df2020Oct.index.name = "Index"
df2020Nov = pd.read_csv("Data/yellow_tripdata_2020-11clean.csv", index_col = 0)
df2020Nov.index.name = "Index"
df2020Dec = pd.read_csv("Data/yellow_tripdata_2020-12clean.csv", index_col = 0)
df2020Dec.index.name = "Index"

# All dates in 2021
df2021Jan = pd.read_csv("Data/yellow_tripdata_2021-01clean.csv", index_col = 0)
df2021Jan.index.name = "Index"
df2021Feb = pd.read_csv("Data/yellow_tripdata_2021-02clean.csv", index_col = 0)
df2021Feb.index.name = "Index"
df2021Mar = pd.read_csv("Data/yellow_tripdata_2021-03clean.csv", index_col = 0)
df2021Mar.index.name = "Index"
df2021Apr = pd.read_csv("Data/yellow_tripdata_2021-04clean.csv", index_col = 0)
df2021Apr.index.name = "Index"
df2021May = pd.read_csv("Data/yellow_tripdata_2021-05clean.csv", index_col = 0)
df2021May.index.name = "Index"
df2021Jun = pd.read_csv("Data/yellow_tripdata_2021-06clean.csv", index_col = 0)
df2021Jun.index.name = "Index"
df2021Jul = pd.read_csv("Data/yellow_tripdata_2021-07clean.csv", index_col = 0)
df2021Jul.index.name = "Index"
df2021Aug = pd.read_csv("Data/yellow_tripdata_2021-08clean.csv", index_col = 0)
df2021Aug.index.name = "Index"
df2021Sep = pd.read_csv("Data/yellow_tripdata_2021-09clean.csv", index_col = 0)
df2021Sep.index.name = "Index"
df2021Oct = pd.read_csv("Data/yellow_tripdata_2021-10clean.csv", index_col = 0)
df2021Oct.index.name = "Index"
df2021Nov = pd.read_csv("Data/yellow_tripdata_2021-11clean.csv", index_col = 0)
df2021Nov.index.name = "Index"
df2021Dec = pd.read_csv("Data/yellow_tripdata_2021-12clean.csv", index_col = 0)
df2021Dec.index.name = "Index"

# %%
df2019Jan
# Out:
#                Date  PULocationID  DOLocationID  passenger_count
# Index
# 0        2019-01-01           151           239              1.0
# 1        2019-01-01           239           246              1.0
# 2        2019-01-01           163           229              1.0
# 3        2019-01-01           229             7              1.0
# 4        2019-01-01           141           234              2.0
# ...             ...           ...           ...              ...
# 7489395  2019-01-31           186            13              2.0
# 7489396  2019-01-31            68           233              1.0
# 7489397  2019-01-31           161           229              1.0
# 7489398  2019-01-31           186           262              2.0
# 7489399  2019-01-31           263             4              1.0
#
# [7489400 rows x 4 columns]

# %%
# create different lists per year
list2019 = [df2019Jan, df2019Feb, df2019Mar, df2019Apr, df2019May, df2019Jun, df2019Jul, df2019Aug, df2019Sep, df2019Oct, df2019Nov, df2019Dec]
list2020 = [df2020Jan, df2020Feb, df2020Mar, df2020Apr, df2020May, df2020Jun, df2020Jul, df2020Aug, df2020Sep, df2020Oct, df2020Nov, df2020Dec]
list2021 = [df2021Jan, df2021Feb, df2021Mar, df2021Apr, df2021May, df2021Jun, df2021Jul, df2021Aug, df2021Sep, df2021Oct, df2021Nov, df2021Dec]
years_list = [list2019, list2020, list2021] # sum up the lists so they can be found easily

# %%
from collections import Counter
# Check for random years

# Initialize a Counter to hold year counts
year_counter = Counter()

# Loop through each year's list of DataFrames
for year_data in years_list:
    for df in year_data:
        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        
        # Extract the year from the Date column and update the counter
        years = df['Date'].dt.year
        year_counter.update(years)

# Print the counts of each year
print(year_counter)
# Out:
# Counter({2019: 81819501, 2021: 28345653, 2020: 23017693, 2009: 642, 2018: 348, 2008: 293, 2022: 49, 2002: 11, 2038: 4, 2029: 4, 2011: 4, 2003: 4, 2033: 3, 2058: 3, 2088: 2, 2001: 2, 2041: 1, 2010: 1, 2090: 1, 2026: 1, 2066: 1, 2004: 1, 2098: 1, 2028: 1})

# %%
# create empty df's to store the data from before and post COVID
preCOVID = pd.DataFrame()
postCOVID = pd.DataFrame()

# loop through both the years list and the months to determine in which df each value should be.
for i in range(3):
    year = years_list[i]
    for k in range(12): #in here year[k] is the dataframe for a single month
        year[k]["Date"] = pd.to_datetime(year[k]["Date"])
        preCOVID_new = year[k][year[k]["Date"] < '2020-03-01'] #check for dates which are before March of 2020 and add them to a new dataframe
        preCOVID = pd.concat([preCOVID, preCOVID_new]) #add new dates from this iteration to the total df
        postCOVID_new = year[k][year[k]["Date"] > '2020-03-31'] #repeat two steps above for post-COVID
        postCOVID = pd.concat([postCOVID, postCOVID_new])

print(preCOVID)
print(postCOVID) #check files
# Out:
#               Date  PULocationID  DOLocationID  passenger_count
# Index
# 0       2019-01-01           151           239              1.0
# 1       2019-01-01           239           246              1.0
# 2       2019-01-01           163           229              1.0
# 3       2019-01-01           229             7              1.0
# 4       2019-01-01           141           234              2.0
# ...            ...           ...           ...              ...
# 2388852 2009-01-01            75           263              1.0
# 2559820 2008-12-31           166           140              2.0
# 2604159 2009-01-01           138           230              2.0
# 2898940 2009-01-01           132            92              1.0
# 3045949 2009-01-01           132           203              1.0
#
# [94037743 rows x 4 columns]
#               Date  PULocationID  DOLocationID  passenger_count
# Index
# 4061591 2088-01-24            41           166              1.0
# ...

# %%
# Filter the data to remove all values which are outside of the range as they are apperentaly in the datasets
preCOVID = preCOVID[(preCOVID['Date'] > '2018-12-31') & (preCOVID['Date'] < '2022-01-01')]
postCOVID = postCOVID[(postCOVID['Date'] > '2018-12-31') & (postCOVID['Date'] < '2022-01-01')]

# %%
## Check data for weird outliers (dates)
outliers1 = ((preCOVID['Date'] < "2019-01-01") | (preCOVID['Date'] > "2021-12-31")).any()
outliers2 = ((postCOVID['Date'] < "2019-01-01") | (postCOVID['Date'] > "2021-12-31")).any() # I wanted to do this in one statement but that gave a memory error :'(
if outliers1 == True or outliers2 == True or (outliers1 == True and outliers2 == True):
    print("The data still contains dates which are not within the research range, please investigate further.")
else:
    print("The data contains no dates outside of the research range. You can continue")
# Out:
# The data contains no dates outside of the research range. You can continue

# %%
# Calculate average number of trips per month in a function

def trips_per_month(df):
    df["Year_Month"] = df["Date"].dt.to_period("M")
    monthlyTrips = df.groupby("Year_Month").size()
    monthlyMean = monthlyTrips.mean()
    return monthlyMean, monthlyTrips

preCOVID_avg, preCOVID_monthly = trips_per_month(preCOVID)
postCOVID_avg, postCOVID_monthly = trips_per_month(postCOVID)

# %%
preCOVID_monthly.plot(title="New York City Taxi trips before and after COVID.", figsize = (7,7), legend = True, ylabel = "Millions of taxi trips")
postCOVID_monthly.plot(xlabel= "Months") # put x-label in the second plot otherwise it will be overwritten
plt.legend(["Trips before COVID", "Trips during COVID"])

# %%
premeanpassenger = preCOVID['passenger_count'].mean()
postmeanpassenger = postCOVID['passenger_count'].mean()

# %%
def average_passengers_per_trip(df):
    # Convert the 'Date' column to a period representing year and month
    df["Year_Month"] = df["Date"].dt.to_period("M")
    
    # Group by 'Year_Month' and calculate total passengers and number of trips
    monthly_data = df.groupby("Year_Month").agg(
        total_passengers=('passenger_count', 'sum'),  # Sum of passengers
        total_trips=('passenger_count', 'size')       # Count of trips
    )
    
    # Calculate average passengers per trip
    monthly_data['average_passengers_per_trip'] = monthly_data['total_passengers'] / monthly_data['total_trips']
    
    # Calculate the overall average
    overall_avg = monthly_data['average_passengers_per_trip'].mean()
    
    return overall_avg, monthly_data['average_passengers_per_trip']

preCOVID_avg, preCOVID_monthly = average_passengers_per_trip(preCOVID)
postCOVID_avg, postCOVID_monthly = average_passengers_per_trip(postCOVID)

# %%
preCOVID_monthly.plot(title="New York City Taxi average number of passengers per trip before and after COVID.", figsize = (7,7), legend = True, ylabel = "Number of passengers per trip")
postCOVID_monthly.plot(xlabel= "Months")
plt.legend([f"Trips before COVID, average = {premeanpassenger:.2f}", f"Trips during COVID, average = {postmeanpassenger:.2f}"])

# %% [markdown]
# # Plotting the graph

# %%
import geopandas as gpd

# %%
map =gpd.read_file("Mapping Equipment/taxi_zones.shp")
map.drop(index = 253, inplace = True) # somehow row 254 was accidentally removed earlier in the PU_DO. Thus remove it here too to make plot possible.

# %%
map.plot() #test
# Out:
# <Axes: >

# %%
PU_DO = preCOVID['PULocationID'].value_counts().reset_index()
PU_DO.columns = ["Location ID", "PU PreCOVID"]
PU_DO.sort_values(by = "Location ID", inplace = True)
PU_DO.set_index("Location ID", inplace = True)
PU_DO["DO PreCOVID"] = preCOVID['DOLocationID'].value_counts().fillna(0)
PU_DO["PU PostCOVID"] = postCOVID['PULocationID'].value_counts().fillna(0)
PU_DO["DO PostCOVID"] = postCOVID['DOLocationID'].value_counts().fillna(0)
print(PU_DO)
# Out:
#              PU PreCOVID  DO PreCOVID  PU PostCOVID  DO PostCOVID
# Location ID
# 1                   1648       188351         599.0       48344.0
# 2                     93           86          14.0          23.0
# 3                   1467         6878         323.0        2692.0
# 4                 156821       403505       32308.0      164310.0
# 5                    353          851         138.0         327.0
# ...                  ...          ...           ...           ...
# 261               543534       437895      141305.0      130332.0
# 262              1162502      1249071      558996.0      615291.0
# 263              1750212      1785687      939960.0      874534.0
# 264               759079       615022      257268.0      184641.0
# 265                19373       213347        6511.0       88090.0
#
# [262 rows x 4 columns]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

map.plot(column = PU_DO['PU PreCOVID'], cmap = "copper", ax = axs[0], legend = True)
axs[0].set_title("Pick-up locations before COVID.")
axs[0].set_xticks([])  # Hides values at x-axis
axs[0].set_yticks([])  # Hides values at y-axis

map.plot(column = PU_DO['PU PostCOVID'], cmap = "copper", ax = axs[1], legend = True)
axs[1].set_title("Pick-up locations after COVID.")
axs[1].set_xticks([])  # Hides values at x-axis
axs[1].set_yticks([])  # Hides values at y-axis

plt.tight_layout()
plt.show()

print("Figure 3: a plot comparing the pick-up locations before and during COVID. Note: for clarity the heatmaps have a different scale. We already know the number of trips is lower.")
# Out:
# Figure 3: a plot comparing the pick-up locations before and during COVID. Note: for clarity the heatmaps have a different scale. We already know the number of trips is lower.

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

map.plot(column = PU_DO['DO PreCOVID'], cmap = "copper", ax = axs[0], legend = True)
axs[0].set_title("Drop-off locations before COVID.")
axs[0].set_xticks([])  # Hides values at x-axis
axs[0].set_yticks([])  # Hides values at y-axis

map.plot(column = PU_DO['DO PostCOVID'], cmap = "copper", ax = axs[1], legend = True)
axs[1].set_title("Drop-off locations after COVID.")
axs[1].set_xticks([])  # Hides values at x-axis
axs[1].set_yticks([])  # Hides values at y-axis

plt.tight_layout()
plt.show()

print("Figure 4: a plot comparing the drop-off locations before and during COVID. Note: for clarity the heatmaps have a different scale. We already know the number of trips is lower.")
# Out:
# Figure 4: a plot comparing the drop-off locations before and during COVID. Note: for clarity the heatmaps have a different scale. We already know the number of trips is lower.
